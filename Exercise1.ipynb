# %% [markdown]
# <a href="https://colab.research.google.com/github/Tsukkei/CCDATSCL_EXERCISES_COM221/blob/main/Exercise1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Exercise 1
#
# In this activity, you will work with the New York City Airbnb Open Data—a popular, messy, and highly realistic dataset used by data analysts and data scientists around the world. The dataset includes thousands of Airbnb listings along with details about hosts, locations, prices, reviews, and more.
#
# <img src="https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcR8Pmq3Gv7y7z_2Xun-OqMIk43kd5u0TXEatw&s"/>
#
#
# To guide your work, you will follow the 6-Step Data Wrangling Process, a professional workflow used in industry:
#
# - Discovering. Become familiar with the data by exploring its structure and observing patterns.
#
# - Structuring. Fix issues related to format, column types, indices, and duplicated records.
#
# - Cleaning. Handle missing values, outliers, and inconsistencies so the dataset becomes trustworthy.
#
# - Enriching. Add new features, aggregate information, and enhance the dataset for deeper insights.
#
# - Validating. Apply rule-based checks to ensure the data meets quality standards.
#
# - Publishing. Export and prepare the cleaned dataset for downstream analysis or reporting.
# Throughout this exercise, you will answer questions and fill in code cells based on these six steps. You will mimic what professional data scientists do when preparing data for business intelligence dashboards, machine learning models, or exploratory analysis.

# %%
import kagglehub
import os
import pandas as pd
import numpy as np

# Download latest version
path = kagglehub.dataset_download("dgomonov/new-york-city-airbnb-open-data")

print("Path to dataset files:", path)

if os.path.isdir(path):
  print(True)

contents = os.listdir(path)
contents

mydataset = path + "/" + contents[0]
mydataset


df = pd.read_csv(mydataset)
# Out:
# Using Colab cache for faster access to the 'new-york-city-airbnb-open-data' dataset.
# Path to dataset files: /kaggle/input/new-york-city-airbnb-open-data
# True

# %% [markdown]
# ## A. Discovering

# %% [markdown]
# Display the first 10 rows

# %%
# put your answer here

df.head(10)
# Out:
#      id                                              name  host_id  \
# 0  2539                Clean & quiet apt home by the park     2787
# 1  2595                             Skylit Midtown Castle     2845
# 2  3647               THE VILLAGE OF HARLEM....NEW YORK !     4632
# 3  3831                   Cozy Entire Floor of Brownstone     4869
# 4  5022  Entire Apt: Spacious Studio/Loft by central park     7192
# 5  5099         Large Cozy 1 BR Apartment In Midtown East     7322
# 6  5121                                   BlissArtsSpace!     7356
# 7  5178                  Large Furnished Room Near B'way      8967
# 8  5203                Cozy Clean Guest Room - Family Apt     7490
# 9  5238                Cute & Cozy Lower East Side 1 bdrm     7549
#
#      host_name neighbourhood_group       neighbourhood  latitude  longitude  \
# 0         John            Brooklyn          Kensington  40.64749  -73.97237
# 1     Jennifer           Manhattan             Midtown  40.75362  -73.98377
# 2    Elisabeth           Manhattan              Harlem  40.80902  -73.94190
# 3  LisaRoxanne            Brooklyn        Clinton Hill  40.68514  -73.95976
# 4        Laura           Manhattan         East Harlem  40.79851  -73.94399
# 5        Chris           Manhattan         Murray Hill  40.74767  -73.97500
# 6        Garon            Brooklyn  Bedford-Stuyvesant  40.68688  -73.95596
# 7     Shunichi           Manhattan      Hell's Kitchen  40.76489  -73.98493
# 8    MaryEllen           Manhattan     Upper West Side  40.80178  -73.96723
# 9          Ben           Manhattan           Chinatown  40.71344  -73.99037
#
#          room_type  price  minimum_nights  number_of_reviews last_review  \
# 0     Private room    149               1                  9  2018-10-19
# 1  Entire home/apt    225               1                 45  2019-05-21
# 2     Private room    150               3                  0         NaN
# 3  Entire home/apt     89               1                270  2019-07-05
# 4  Entire home/apt     80              10                  9  2018-11-19
# 5  Entire home/apt    200               3                 74  2019-06-22
# 6     Private room     60              45                 49  2017-10-05
# 7     Private room     79               2                430  2019-06-24
# 8     Private room     79               2                118  2017-07-21
# 9  Entire home/apt    150               1                160  2019-06-09
#
#    reviews_per_month  calculated_host_listings_count  availability_365
# 0               0.21                               6               365
# 1               0.38                               2               355
# 2                NaN                               1               365
# 3               4.64                               1               194
# 4               0.10                               1                 0
# 5               0.59                               1               129
# 6               0.40                               1                 0
# 7               3.47                               1               220
# 8               0.99                               1                 0
# 9               1.33                               4               188

# %% [markdown]
# Display the column names:

# %%
# put your answer here
df.columns
# Out:
# Index(['id', 'name', 'host_id', 'host_name', 'neighbourhood_group',
#        'neighbourhood', 'latitude', 'longitude', 'room_type', 'price',
#        'minimum_nights', 'number_of_reviews', 'last_review',
#        'reviews_per_month', 'calculated_host_listings_count',
#        'availability_365'],
#       dtype='object')

# %% [markdown]
# Display the dataframe shape:

# %%
# put your answer here
df.shape
# Out:
# (48895, 16)

# %% [markdown]
# Identify the numerical features:

# %%
# put your answer here

df.select_dtypes(include=['number']).columns
# Out:
# Index(['id', 'host_id', 'latitude', 'longitude', 'price', 'minimum_nights',
#        'number_of_reviews', 'reviews_per_month',
#        'calculated_host_listings_count', 'availability_365'],
#       dtype='object')

# %% [markdown]
# Identify the categorical features

# %%
# put your answer here

df.select_dtypes(include='object').columns
# Out:
# Index(['name', 'host_name', 'neighbourhood_group', 'neighbourhood',
#        'room_type', 'last_review'],
#       dtype='object')

# %% [markdown]
# What are the top 5 questions this dataset might help answer?

# %%
# put your answer here

#What are the most popular neighborhoods for Airbnb listings and their average prices?

#What is the distribution of room types (e.g., 'Private room', 'Entire home/apt') and how does room type affect pricing?

#Is there a correlation between the number of reviews, reviews per month, and the availability of a listing?

#Who are the top hosts with the most listings, and how does their listing count relate to their average prices or review counts?

#How does the price of listings vary across different neighbourhood groups and specific neighbourhoods in NYC?

# %% [markdown]
# ## B. Structuring

# %% [markdown]
# Check if the dataset has proper column types

# %%
# put your answer here

df.dtypes
# Out:
# id                                  int64
# name                               object
# host_id                             int64
# host_name                          object
# neighbourhood_group                object
# neighbourhood                      object
# latitude                          float64
# longitude                         float64
# room_type                          object
# price                               int64
# minimum_nights                      int64
# number_of_reviews                   int64
# last_review                        object
# reviews_per_month                 float64
# calculated_host_listings_count      int64
# availability_365                    int64
# dtype: object

# %% [markdown]
# Check if the dataset has index issues

# %%
# put your answer here

df.index
# Out:
# RangeIndex(start=0, stop=48895, step=1)

# %% [markdown]
# Check if the dataset has duplicated rows

# %%
# put your answer here

df.duplicated().sum()
# Out:
# np.int64(0)

# %% [markdown]
# Convert columns to correct types (e.g., dates → datetime).

# %%
# put your answer here

df['last_review'] = pd.to_datetime(df['last_review'])
df['last_review']
# Out:
# 0       2018-10-19
# 1       2019-05-21
# 2              NaT
# 3       2019-07-05
# 4       2018-11-19
#            ...
# 48890          NaT
# 48891          NaT
# 48892          NaT
# 48893          NaT
# 48894          NaT
# Name: last_review, Length: 48895, dtype: datetime64[ns]

# %% [markdown]
# Identify at least one structural issue and describe how to fix it.

# %%
# put your answer here

#One structural issue is that the 'last_review' column was initially of type 'object' (string), but it represents a date. This was fixed by converting it to a datetime type using pd.to_datetime().

# %% [markdown]
# ## C. Cleaning

# %% [markdown]
# Check for missing values

# %%
# put your answer here

df.isnull().sum()
# Out:
# id                                    0
# name                                 16
# host_id                               0
# host_name                            21
# neighbourhood_group                   0
# neighbourhood                         0
# latitude                              0
# longitude                             0
# room_type                             0
# price                                 0
# minimum_nights                        0
# number_of_reviews                     0
# last_review                       10052
# reviews_per_month                 10052
# calculated_host_listings_count        0
# availability_365                      0
# dtype: int64

# %% [markdown]
# Check for outliers in `minimum_nights`

# %%
# put your answer here

df['minimum_nights'].describe()
# Out:
# count    48895.000000
# mean         7.029962
# std         20.510550
# min          1.000000
# 25%          1.000000
# 50%          3.000000
# 75%          5.000000
# max       1250.000000
# Name: minimum_nights, dtype: float64

# %% [markdown]
# Check for invalid values (e.g., price ≤ 0)

# %%
# put your answer here

df[df['price'] <= 0]
# Out:
#              id                                               name    host_id  \
# 23161  18750597  Huge Brooklyn Brownstone Living, Close to it all.    8993084
# 25433  20333471      ★Hostel Style Room | Ideal Traveling Buddies★  131697576
# 25634  20523843    MARTIAL LOFT 3: REDEMPTION (upstairs, 2nd room)   15787004
# 25753  20608117                    Sunny, Quiet Room in Greenpoint    1641537
# 25778  20624541      Modern apartment in the heart of Williamsburg   10132166
# 25794  20639628  Spacious comfortable master bedroom with nice ...   86327101
# 25795  20639792  Contemporary bedroom in brownstone with nice view   86327101
# 25796  20639914       Cozy yet spacious private brownstone bedroom   86327101
# 26259  20933849                              the best you can find   13709292
# 26841  21291569  Coliving in Brooklyn! Modern design / Shared room  101970559
# 26866  21304320             Best Coliving space ever! Shared room.  101970559
#
#           host_name neighbourhood_group       neighbourhood  latitude  \
# 23161      Kimberly            Brooklyn  Bedford-Stuyvesant  40.69023
# 25433        Anisha               Bronx     East Morrisania  40.83296
# 25634  Martial Loft            Brooklyn            Bushwick  40.69467
# 25753        Lauren            Brooklyn          Greenpoint  40.72462
# 25778       Aymeric            Brooklyn        Williamsburg  40.70838
# 25794       Adeyemi            Brooklyn  Bedford-Stuyvesant  40.68173
# 25795       Adeyemi            Brooklyn  Bedford-Stuyvesant  40.68279
# 25796       Adeyemi            Brooklyn  Bedford-Stuyvesant  40.68258
# 26259        Qiuchi           Manhattan         Murray Hill  40.75091
# 26841        Sergii            Brooklyn            Bushwick  40.69211
# 26866        Sergii            Brooklyn            Bushwick  40.69166
#
#        longitude        room_type  price  minimum_nights  number_of_reviews  \
# 23161  -73.95428     Private room      0               4                  1
# 25433  -73.88668     Private room      0               2                 55
# 25634  -73.92433     Private room      0               2                 16
# 25753  -73.94072     Private room      0               2                 12
# 25778  -73.94645  Entire home/apt      0               5                  3
# 25794  -73.91342     Private room      0               1                 93
# 25795  -73.91170     Private room      0               1                 95
# 25796  -73.91284     Private room      0               1                 95
# 26259  -73.97597  Entire home/apt      0               3                  0
# 26841  -73.90670      Shared room      0              30                  2
# 26866  -73.90928      Shared room      0              30                  5
#
#       last_review  reviews_per_month  calculated_host_listings_count  \
# 23161  2018-01-06               0.05                               4
# 25433  2019-06-24               2.56                               4
# 25634  2019-05-18               0.71                               5
# 25753  2017-10-27               0.53                               2
# 25778  2018-01-02               0.15                               1
# 25794  2019-06-15               4.28                               6
# 25795  2019-06-21               4.37                               6
# 25796  2019-06-23               4.35                               6
# 26259         NaT                NaN                               1
# 26841  2019-06-22               0.11                               6
# 26866  2019-05-24               0.26                               6
#
#        availability_365
# 23161                28
# 25433               127
# 25634                 0
# 25753                 0
# 25778                73
# 25794               176
# 25795               232
# 25796               222
# 26259                 0
# 26841               333
# 26866               139

# %% [markdown]
# Apply a missing-value strategy (drop, fill, or flag)

# %%
# put your answer here

df.dropna(inplace=True)
df.isnull().sum()
# Out:
# id                                0
# name                              0
# host_id                           0
# host_name                         0
# neighbourhood_group               0
# neighbourhood                     0
# latitude                          0
# longitude                         0
# room_type                         0
# price                             0
# minimum_nights                    0
# number_of_reviews                 0
# last_review                       0
# reviews_per_month                 0
# calculated_host_listings_count    0
# availability_365                  0
# dtype: int64

# %% [markdown]
# Apply an outlier-handling strategy

# %%
# put your answer here

df = df[df['price'] > 0]
df['price'].describe()
# Out:
# count    38811.000000
# mean       142.369199
# std        197.006883
# min         10.000000
# 25%         69.000000
# 50%        101.000000
# 75%        170.000000
# max      10000.000000
# Name: price, dtype: float64

# %% [markdown]
# ## D. Enriching

# %% [markdown]
# Create at least 3 new variables:
# - price_per_minimum_night
# - review_rate_per_month (combine ratings + frequency)
# - is_expensive (boolean flag based on price threshold)

# %%
# put your answer here

df['price_per_minimum_night'] = df['price'] / df['minimum_nights']
df['review_rate_per_month'] = df['number_of_reviews'] * df['reviews_per_month']
df['is_expensive'] = df['price'] > 200
df.head()
# Out:
#      id                                              name  host_id  \
# 0  2539                Clean & quiet apt home by the park     2787
# 1  2595                             Skylit Midtown Castle     2845
# 3  3831                   Cozy Entire Floor of Brownstone     4869
# 4  5022  Entire Apt: Spacious Studio/Loft by central park     7192
# 5  5099         Large Cozy 1 BR Apartment In Midtown East     7322
#
#      host_name neighbourhood_group neighbourhood  latitude  longitude  \
# 0         John            Brooklyn    Kensington  40.64749  -73.97237
# 1     Jennifer           Manhattan       Midtown  40.75362  -73.98377
# 3  LisaRoxanne            Brooklyn  Clinton Hill  40.68514  -73.95976
# 4        Laura           Manhattan   East Harlem  40.79851  -73.94399
# 5        Chris           Manhattan   Murray Hill  40.74767  -73.97500
#
#          room_type  price  minimum_nights  number_of_reviews last_review  \
# 0     Private room    149               1                  9  2018-10-19
# 1  Entire home/apt    225               1                 45  2019-05-21
# 3  Entire home/apt     89               1                270  2019-07-05
# 4  Entire home/apt     80              10                  9  2018-11-19
# 5  Entire home/apt    200               3                 74  2019-06-22
#
#    reviews_per_month  calculated_host_listings_count  availability_365  \
# 0               0.21                               6               365
# 1               0.38                               2               355
# 3               4.64                               1               194
# 4               0.10                               1                 0
# 5               0.59                               1               129
#
#    price_per_minimum_night  review_rate_per_month  is_expensive
# 0               149.000000                   1.89         False
# 1               225.000000                  17.10          True
# 3                89.000000                1252.80         False
# 4                 8.000000                   0.90         False
# 5                66.666667                  43.66         False

# %% [markdown]
# Create 1 aggregated summary table
#
# (e.g. average price per neighborhood, number of hosts per borough)

# %%
# put your answer here

aggregated_data = df.groupby(['neighbourhood_group', 'room_type']).agg(
    average_price=('price', 'mean'),
    average_reviews=('number_of_reviews', 'mean'),
    total_host_listings=('calculated_host_listings_count', 'sum')
).reset_index()

display(aggregated_data)
# Out:
#    neighbourhood_group        room_type  average_price  average_reviews  \
# 0                Bronx  Entire home/apt     120.938312        37.629870
# 1                Bronx     Private room      57.202677        31.084130
# 2                Bronx      Shared room      56.930233        10.046512
# 3             Brooklyn  Entire home/apt     171.302893        32.695636
# 4             Brooklyn     Private room      73.404684        26.720316
# 5             Brooklyn      Shared room      45.774306        20.090278
# 6            Manhattan  Entire home/apt     230.200964        23.592752
# 7            Manhattan     Private room     106.607488        33.130731
# 8            Manhattan      Shared room      77.980337        28.853933
# 9               Queens  Entire home/apt     139.225603        34.812859
# 10              Queens     Private room      69.302838        34.918969
# 11              Queens      Shared room      64.467105        18.059211
# 12       Staten Island  Entire home/apt     125.366667        39.046667
# 13       Staten Island     Private room      57.584906        35.660377
# 14       Staten Island      Shared room      57.600000         2.800000
#
#     total_host_listings
# 0                   566
# 1                  1188
# 2                   172
# 3                 14911
# 4                 19903
# 5                  1861
# 6                124379
# 7                 20098
# 8                  1358
# 9                  2957
# 10                11782
# 11                  602
# 12                  236
# 13                  489
# 14                   25

# %% [markdown]
# ## E. Validating

# %% [markdown]
# Create at least 3 validation checks
# - Price must be positive.
# - Host ID should not be null.
# - Minimum nights must be ≥ 1.
# - Generate a validation report:
# - Count of rows violating each rule.
#
# Decide if invalid rows (if any) should be removed or corrected?

# %%
# put your answer here
# Validation Check 1:
price_violation_count = df[df['price'] <= 0].shape[0]

# Validation Check 2:
host_id_violation_count = df['host_id'].isnull().sum()

# Validation Check 3:
minimum_nights_violation_count = df[df['minimum_nights'] < 1].shape[0]

# validation report
validation_report = pd.DataFrame({
    'Validation Rule': [
        'Price must be positive',
        'Host ID should not be null',
        'Minimum nights must be \u2265 1'
    ],
    'Violating Rows Count': [
        price_violation_count,
        host_id_violation_count,
        minimum_nights_violation_count
    ]
})

display(validation_report)

# Decide if invalid rows (if any) should be removed or corrected?
if price_violation_count == 0 and host_id_violation_count == 0 and minimum_nights_violation_count == 0:
    print("\nDecision on invalid rows:")
    print("Based on the cleaning steps performed earlier:")
    print(" - Rows with `price <= 0` were already removed.")
    print(" - Rows with missing `host_name` (and implicitly `host_id`) were removed through `dropna()`.")
    print(" - `minimum_nights` are all \u2265 1 based on previous descriptive analysis.")
    print("Therefore, at this stage, no further rows need to be removed or corrected based on these specific rules, as the dataset already adheres to them.")
else:
    print("\nDecision on invalid rows: Some violations found. Review the report above for details and consider removal or correction based on the context.")
# Out:
#               Validation Rule  Violating Rows Count
# 0      Price must be positive                     0
# 1  Host ID should not be null                     0
# 2  Minimum nights must be ≥ 1                     0
# Decision on invalid rows:
# Based on the cleaning steps performed earlier:
#  - Rows with `price <= 0` were already removed.
#  - Rows with missing `host_name` (and implicitly `host_id`) were removed through `dropna()`.
#  - `minimum_nights` are all ≥ 1 based on previous descriptive analysis.
# Therefore, at this stage, no further rows need to be removed or corrected based on these specific rules, as the dataset already adheres to them.

# %% [markdown]
# ## F. Publishing

# %% [markdown]
# Select final columns for publication.

# %%
# put your answer here

final_columns = [
    'id', 'name', 'host_id', 'host_name', 'neighbourhood_group', 'neighbourhood',
    'latitude', 'longitude', 'room_type', 'price', 'minimum_nights',
    'number_of_reviews', 'last_review', 'reviews_per_month',
    'calculated_host_listings_count', 'availability_365',
    'price_per_minimum_night', 'review_rate_per_month', 'is_expensive'
]

df_published = df[final_columns]
display(df_published.head())
# Out:
#      id                                              name  host_id  \
# 0  2539                Clean & quiet apt home by the park     2787
# 1  2595                             Skylit Midtown Castle     2845
# 3  3831                   Cozy Entire Floor of Brownstone     4869
# 4  5022  Entire Apt: Spacious Studio/Loft by central park     7192
# 5  5099         Large Cozy 1 BR Apartment In Midtown East     7322
#
#      host_name neighbourhood_group neighbourhood  latitude  longitude  \
# 0         John            Brooklyn    Kensington  40.64749  -73.97237
# 1     Jennifer           Manhattan       Midtown  40.75362  -73.98377
# 3  LisaRoxanne            Brooklyn  Clinton Hill  40.68514  -73.95976
# 4        Laura           Manhattan   East Harlem  40.79851  -73.94399
# 5        Chris           Manhattan   Murray Hill  40.74767  -73.97500
#
#          room_type  price  minimum_nights  number_of_reviews last_review  \
# 0     Private room    149               1                  9  2018-10-19
# 1  Entire home/apt    225               1                 45  2019-05-21
# 3  Entire home/apt     89               1                270  2019-07-05
# 4  Entire home/apt     80              10                  9  2018-11-19
# 5  Entire home/apt    200               3                 74  2019-06-22
#
#    reviews_per_month  calculated_host_listings_count  availability_365  \
# 0               0.21                               6               365
# 1               0.38                               2               355
# 3               4.64                               1               194
# 4               0.10                               1                 0
# 5               0.59                               1               129
#
#    price_per_minimum_night  review_rate_per_month  is_expensive
# 0               149.000000                   1.89         False
# 1               225.000000                  17.10          True
# 3                89.000000                1252.80         False
# 4                 8.000000                   0.90         False
# 5                66.666667                  43.66         False

# %% [markdown]
# Export cleaned dataset as "cleaned_airbnb.csv"

# %%
# put your answer here

df_published.to_csv('cleaned_airbnb.csv', index=False)

# %% [markdown]
# Export summary reports (e.g., validation or aggregations) as CSV.

# %%
# put your answer here

df_published.to_csv('summary_report.csv', index=False)

# %%
df.head(10)
# Out:
#       id                                              name  host_id  \
# 0   2539                Clean & quiet apt home by the park     2787
# 1   2595                             Skylit Midtown Castle     2845
# 3   3831                   Cozy Entire Floor of Brownstone     4869
# 4   5022  Entire Apt: Spacious Studio/Loft by central park     7192
# 5   5099         Large Cozy 1 BR Apartment In Midtown East     7322
# 6   5121                                   BlissArtsSpace!     7356
# 7   5178                  Large Furnished Room Near B'way      8967
# 8   5203                Cozy Clean Guest Room - Family Apt     7490
# 9   5238                Cute & Cozy Lower East Side 1 bdrm     7549
# 10  5295                  Beautiful 1br on Upper West Side     7702
#
#       host_name neighbourhood_group       neighbourhood  latitude  longitude  \
# 0          John            Brooklyn          Kensington  40.64749  -73.97237
# 1      Jennifer           Manhattan             Midtown  40.75362  -73.98377
# 3   LisaRoxanne            Brooklyn        Clinton Hill  40.68514  -73.95976
# 4         Laura           Manhattan         East Harlem  40.79851  -73.94399
# 5         Chris           Manhattan         Murray Hill  40.74767  -73.97500
# 6         Garon            Brooklyn  Bedford-Stuyvesant  40.68688  -73.95596
# 7      Shunichi           Manhattan      Hell's Kitchen  40.76489  -73.98493
# 8     MaryEllen           Manhattan     Upper West Side  40.80178  -73.96723
# 9           Ben           Manhattan           Chinatown  40.71344  -73.99037
# 10         Lena           Manhattan     Upper West Side  40.80316  -73.96545
#
#           room_type  price  minimum_nights  number_of_reviews last_review  \
# 0      Private room    149               1                  9  2018-10-19
# 1   Entire home/apt    225               1                 45  2019-05-21
# 3   Entire home/apt     89               1                270  2019-07-05
# 4   Entire home/apt     80              10                  9  2018-11-19
# 5   Entire home/apt    200               3                 74  2019-06-22
# 6      Private room     60              45                 49  2017-10-05
# 7      Private room     79               2                430  2019-06-24
# 8      Private room     79               2                118  2017-07-21
# 9   Entire home/apt    150               1                160  2019-06-09
# 10  Entire home/apt    135               5                 53  2019-06-22
#
#     reviews_per_month  calculated_host_listings_count  availability_365  \
# 0                0.21                               6               365
# 1                0.38                               2               355
# 3                4.64                               1               194
# 4                0.10                               1                 0
# 5                0.59                               1               129
# 6                0.40                               1                 0
# 7                3.47                               1               220
# 8                0.99                               1                 0
# 9                1.33                               4               188
# 10               0.43                               1                 6
#
#     price_per_minimum_night  review_rate_per_month  is_expensive
# 0                149.000000                   1.89         False
# 1                225.000000                  17.10          True
# 3                 89.000000                1252.80         False
# 4                  8.000000                   0.90         False
# 5                 66.666667                  43.66         False
# 6                  1.333333                  19.60         False
# 7                 39.500000                1492.10         False
# 8                 39.500000                 116.82         False
# 9                150.000000                 212.80         False
# 10                27.000000                  22.79         False
